# %% [markdown]
# # Configuring the Logging Output for TARDIS

# %% [markdown]
# **TARDIS** has a Notebook logger that logs information of Simulation runs. The logs allows to access vital information regarding the execution sequence, data for plasma stratification & progress of the simulation.<br>
# **TARDIS** allows configuring the logger via *Functional Arguments* as well as *YAML Parameters*.
# The following code snippets are some of the possible configuration that is available for the notebook logging done with TARDIS simulation.

# %% [markdown]
# ## Default Configuration

# %% [markdown]
# The default configuration of the Notebook Simulation logger is such that it doesn't output any logs.

# %% [markdown]
# The output simulation logging, while executing the **TARDIS** simulation (default behaviour), can be seen below:

# %%
from tardis import run_tardis
from tardis.io.atom_data.util import download_atom_data
# Out:
# /usr/share/miniconda3/envs/tardis/lib/python3.7/importlib/_bootstrap.py:219: QAWarning: pyne.data is not yet QA compliant.
#   return f(*args, **kwds)
# Iterations:          0/? [00:00<?, ?it/s]
# Packets:             0/? [00:00<?, ?it/s]

# %%
download_atom_data('kurucz_cd23_chianti_H_He')

# %%
sim = run_tardis("tardis_config_logger.yml", show_cplots=False)
# Out:
# [py.warnings         ][WARNING]  /usr/share/miniconda3/envs/tardis/lib/python3.7/site-packages/traitlets/traitlets.py:3036: FutureWarning: --rc={'figure.dpi': 96} for dict-traits is deprecated in traitlets 5.0. You can pass --rc <key=value> ... multiple times to add items to a dict.
#   FutureWarning,
#  (warnings.py:110)
# [py.warnings         ][WARNING]  /usr/share/miniconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# TqdmHBox(children=(HTML(value='Iterations:', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# TqdmHBox(children=(HTML(value='Packets:   ', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# VBox(children=(FigureWidget({
#     'data': [{'type': 'scatter', 'uid': '3a05bdc0-85ad-4b04-b0ea-6440878d2965', …
# [py.warnings         ][WARNING]  /usr/share/miniconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning:
#
# divide by zero encountered in double_scalars
#
#  (warnings.py:110)

# %% [markdown]
# It can be examined that the logs are not printed.<br> The logging level, by default, is set to `CRITICAL`. Logs will only be captured if any `CRITICAL` level logs are encountered while running the simulation.

# %% [markdown]
# ## Logging Configuration (Functional Arguments)

# %% [markdown]
# The `run_tardis()` function from the `tardis module` has two functional arguments:`log_level` & `specific_log_level`.

# %% [markdown]
# <div class="alert alert-info" role="alert">
#     Both <strong>log_level</strong> & <strong>specific_log_level</strong> are optional arguments for the <strong>run_tardis()</strong> function, however, if <strong>specific_log_level</strong> argument is used then, <strong>log_level</strong> must be set to a particular level.
# </div>

# %% [markdown]
# ### `log_level`

# %% [markdown]
# The `log_level` argument can be passed in `run_tardis()` to set the logging level for the simulation. The input for this argument **must be** one of the following: **Notset, Debug, Info, Warning, Error** or **Critical**.

# %%
sim = run_tardis("tardis_config_logger.yml", log_level="Info", show_cplots=False)
# Out:
# log_level is defined both in Functional Argument & YAML Configuration {debug section}
# log_level = INFO will be used for Log Level Determination
#
# [tardis.plasma.standard_plasmas][INFO   ]  Reading Atomic Data from kurucz_cd23_chianti_H_He.h5 (standard_plasmas.py:92)
# [tardis.io.atom_data.util][INFO   ]  Atom Data kurucz_cd23_chianti_H_He.h5 not found in local path.
# 	Exists in TARDIS Data repo /home/runner/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (util.py:34)
# [tardis.io.atom_data.base][INFO   ]  Reading Atom Data with: UUID = 6f7b09e887a311e7a06b246e96350010 MD5  = 864f1753714343c41f99cb065710cace  (base.py:204)
# [tardis.io.atom_data.base][INFO   ]  Non provided Atomic Data: synpp_refs, photoionization_data, yg_data, two_photon_data (base.py:209)
# [tardis.simulation.base][INFO   ]  Starting iteration 1 of 5 (base.py:367)
# TqdmHBox(children=(HTML(value='Iterations:', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# TqdmHBox(children=(HTML(value='Packets:   ', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 7.947e+42 erg / s
# 	Luminosity absorbed  = 2.654e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Plasma stratification: (base.py:503)
# <style  type="text/css" >
# </style><table id="T_e35a4f02_0492_11ec_900f_000d3adfbea8" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e35a4f02_0492_11ec_900f_000d3adfbea8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e35a4f02_0492_11ec_900f_000d3adfbea8row0_col0" class="data row0 col0" >9.93e+03</td>
#                         <td id="T_e35a4f02_0492_11ec_900f_000d3adfbea8row0_col1" class="data row0 col1" >1.03e+04</td>
#                         <td id="T_e35a4f02_0492_11ec_900f_000d3adfbea8row0_col2" class="data row0 col2" >0.4</td>
#                         <td id="T_e35a4f02_0492_11ec_900f_000d3adfbea8row0_col3" class="data row0 col3" >0.481</td>
#             </tr>
#             <tr>
#                         <th id="T_e35a4f02_0492_11ec_900f_000d3adfbea8level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_e35a4f02_0492_11ec_900f_000d3adfbea8row1_col0" class="data row1 col0" >9.85e+03</td>
#                         <td id="T_e35a4f02_0492_11ec_900f_000d3adfbea8row1_col1" class="data row1 col1" >1.03e+04</td>
#                         <td id="T_e35a4f02_0492_11ec_900f_000d3adfbea8row1_col2" class="data row1 col2" >0.211</td>
#                         <td id="T_e35a4f02_0492_11ec_900f_000d3adfbea8row1_col3" class="data row1 col3" >0.193</td>
#             </tr>
#             <tr>
#                         <th id="T_e35a4f02_0492_11ec_900f_000d3adfbea8level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_e35a4f02_0492_11ec_900f_000d3adfbea8row2_col0" class="data row2 col0" >9.78e+03</td>
#                         <td id="T_e35a4f02_0492_11ec_900f_000d3adfbea8row2_col1" class="data row2 col1" >1.02e+04</td>
#                         <td id="T_e35a4f02_0492_11ec_900f_000d3adfbea8row2_col2" class="data row2 col2" >0.143</td>
#                         <td id="T_e35a4f02_0492_11ec_900f_000d3adfbea8row2_col3" class="data row2 col3" >0.112</td>
#             </tr>
#             <tr>
#                         <th id="T_e35a4f02_0492_11ec_900f_000d3adfbea8level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_e35a4f02_0492_11ec_900f_000d3adfbea8row3_col0" class="data row3 col0" >9.71e+03</td>
#                         <td id="T_e35a4f02_0492_11ec_900f_000d3adfbea8row3_col1" class="data row3 col1" >9.98e+03</td>
#                         <td id="T_e35a4f02_0492_11ec_900f_000d3adfbea8row3_col2" class="data row3 col2" >0.105</td>
#                         <td id="T_e35a4f02_0492_11ec_900f_000d3adfbea8row3_col3" class="data row3 col3" >0.0826</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]  Current t_inner = 9933.952 K
# 	Expected t_inner for next iteration = 11468.808 K
#  (base.py:531)
# VBox(children=(FigureWidget({
#     'data': [{'type': 'scatter', 'uid': '7182eb1a-5b21-475f-88e0-6cebbc027390', …
# [tardis.simulation.base][INFO   ]  Starting iteration 2 of 5 (base.py:367)
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 1.413e+43 erg / s
# 	Luminosity absorbed  = 4.704e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Plasma stratification: (base.py:503)
# <style  type="text/css" >
# </style><table id="T_e3920eec_0492_11ec_900f_000d3adfbea8" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e3920eec_0492_11ec_900f_000d3adfbea8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e3920eec_0492_11ec_900f_000d3adfbea8row0_col0" class="data row0 col0" >1.03e+04</td>
#                         <td id="T_e3920eec_0492_11ec_900f_000d3adfbea8row0_col1" class="data row0 col1" >1.15e+04</td>
#                         <td id="T_e3920eec_0492_11ec_900f_000d3adfbea8row0_col2" class="data row0 col2" >0.481</td>
#                         <td id="T_e3920eec_0492_11ec_900f_000d3adfbea8row0_col3" class="data row0 col3" >0.555</td>
#             </tr>
#             <tr>
#                         <th id="T_e3920eec_0492_11ec_900f_000d3adfbea8level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_e3920eec_0492_11ec_900f_000d3adfbea8row1_col0" class="data row1 col0" >1.03e+04</td>
#                         <td id="T_e3920eec_0492_11ec_900f_000d3adfbea8row1_col1" class="data row1 col1" >1.17e+04</td>
#                         <td id="T_e3920eec_0492_11ec_900f_000d3adfbea8row1_col2" class="data row1 col2" >0.193</td>
#                         <td id="T_e3920eec_0492_11ec_900f_000d3adfbea8row1_col3" class="data row1 col3" >0.203</td>
#             </tr>
#             <tr>
#                         <th id="T_e3920eec_0492_11ec_900f_000d3adfbea8level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_e3920eec_0492_11ec_900f_000d3adfbea8row2_col0" class="data row2 col0" >1.02e+04</td>
#                         <td id="T_e3920eec_0492_11ec_900f_000d3adfbea8row2_col1" class="data row2 col1" >1.13e+04</td>
#                         <td id="T_e3920eec_0492_11ec_900f_000d3adfbea8row2_col2" class="data row2 col2" >0.112</td>
#                         <td id="T_e3920eec_0492_11ec_900f_000d3adfbea8row2_col3" class="data row2 col3" >0.135</td>
#             </tr>
#             <tr>
#                         <th id="T_e3920eec_0492_11ec_900f_000d3adfbea8level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_e3920eec_0492_11ec_900f_000d3adfbea8row3_col0" class="data row3 col0" >9.98e+03</td>
#                         <td id="T_e3920eec_0492_11ec_900f_000d3adfbea8row3_col1" class="data row3 col1" >1.1e+04</td>
#                         <td id="T_e3920eec_0492_11ec_900f_000d3adfbea8row3_col2" class="data row3 col2" >0.0826</td>
#                         <td id="T_e3920eec_0492_11ec_900f_000d3adfbea8row3_col3" class="data row3 col3" >0.0998</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]  Current t_inner = 11468.808 K
# 	Expected t_inner for next iteration = 9929.475 K
#  (base.py:531)
# [tardis.simulation.base][INFO   ]  Starting iteration 3 of 5 (base.py:367)
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 8.259e+42 erg / s
# 	Luminosity absorbed  = 2.337e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Plasma stratification: (base.py:503)
# <style  type="text/css" >
# </style><table id="T_e3aea3a4_0492_11ec_900f_000d3adfbea8" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e3aea3a4_0492_11ec_900f_000d3adfbea8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e3aea3a4_0492_11ec_900f_000d3adfbea8row0_col0" class="data row0 col0" >1.15e+04</td>
#                         <td id="T_e3aea3a4_0492_11ec_900f_000d3adfbea8row0_col1" class="data row0 col1" >1.03e+04</td>
#                         <td id="T_e3aea3a4_0492_11ec_900f_000d3adfbea8row0_col2" class="data row0 col2" >0.555</td>
#                         <td id="T_e3aea3a4_0492_11ec_900f_000d3adfbea8row0_col3" class="data row0 col3" >0.468</td>
#             </tr>
#             <tr>
#                         <th id="T_e3aea3a4_0492_11ec_900f_000d3adfbea8level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_e3aea3a4_0492_11ec_900f_000d3adfbea8row1_col0" class="data row1 col0" >1.17e+04</td>
#                         <td id="T_e3aea3a4_0492_11ec_900f_000d3adfbea8row1_col1" class="data row1 col1" >1.05e+04</td>
#                         <td id="T_e3aea3a4_0492_11ec_900f_000d3adfbea8row1_col2" class="data row1 col2" >0.203</td>
#                         <td id="T_e3aea3a4_0492_11ec_900f_000d3adfbea8row1_col3" class="data row1 col3" >0.181</td>
#             </tr>
#             <tr>
#                         <th id="T_e3aea3a4_0492_11ec_900f_000d3adfbea8level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_e3aea3a4_0492_11ec_900f_000d3adfbea8row2_col0" class="data row2 col0" >1.13e+04</td>
#                         <td id="T_e3aea3a4_0492_11ec_900f_000d3adfbea8row2_col1" class="data row2 col1" >1.05e+04</td>
#                         <td id="T_e3aea3a4_0492_11ec_900f_000d3adfbea8row2_col2" class="data row2 col2" >0.135</td>
#                         <td id="T_e3aea3a4_0492_11ec_900f_000d3adfbea8row2_col3" class="data row2 col3" >0.108</td>
#             </tr>
#             <tr>
#                         <th id="T_e3aea3a4_0492_11ec_900f_000d3adfbea8level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_e3aea3a4_0492_11ec_900f_000d3adfbea8row3_col0" class="data row3 col0" >1.1e+04</td>
#                         <td id="T_e3aea3a4_0492_11ec_900f_000d3adfbea8row3_col1" class="data row3 col1" >1.03e+04</td>
#                         <td id="T_e3aea3a4_0492_11ec_900f_000d3adfbea8row3_col2" class="data row3 col2" >0.0998</td>
#                         <td id="T_e3aea3a4_0492_11ec_900f_000d3adfbea8row3_col3" class="data row3 col3" >0.0779</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]  Current t_inner = 9929.475 K
# 	Expected t_inner for next iteration = 11245.497 K
#  (base.py:531)
# [tardis.simulation.base][INFO   ]  Starting iteration 4 of 5 (base.py:367)
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 1.299e+43 erg / s
# 	Luminosity absorbed  = 4.407e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Plasma stratification: (base.py:503)
# <style  type="text/css" >
# </style><table id="T_e3c94a88_0492_11ec_900f_000d3adfbea8" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e3c94a88_0492_11ec_900f_000d3adfbea8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e3c94a88_0492_11ec_900f_000d3adfbea8row0_col0" class="data row0 col0" >1.03e+04</td>
#                         <td id="T_e3c94a88_0492_11ec_900f_000d3adfbea8row0_col1" class="data row0 col1" >1.14e+04</td>
#                         <td id="T_e3c94a88_0492_11ec_900f_000d3adfbea8row0_col2" class="data row0 col2" >0.468</td>
#                         <td id="T_e3c94a88_0492_11ec_900f_000d3adfbea8row0_col3" class="data row0 col3" >0.527</td>
#             </tr>
#             <tr>
#                         <th id="T_e3c94a88_0492_11ec_900f_000d3adfbea8level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_e3c94a88_0492_11ec_900f_000d3adfbea8row1_col0" class="data row1 col0" >1.05e+04</td>
#                         <td id="T_e3c94a88_0492_11ec_900f_000d3adfbea8row1_col1" class="data row1 col1" >1.13e+04</td>
#                         <td id="T_e3c94a88_0492_11ec_900f_000d3adfbea8row1_col2" class="data row1 col2" >0.181</td>
#                         <td id="T_e3c94a88_0492_11ec_900f_000d3adfbea8row1_col3" class="data row1 col3" >0.225</td>
#             </tr>
#             <tr>
#                         <th id="T_e3c94a88_0492_11ec_900f_000d3adfbea8level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_e3c94a88_0492_11ec_900f_000d3adfbea8row2_col0" class="data row2 col0" >1.05e+04</td>
#                         <td id="T_e3c94a88_0492_11ec_900f_000d3adfbea8row2_col1" class="data row2 col1" >1.12e+04</td>
#                         <td id="T_e3c94a88_0492_11ec_900f_000d3adfbea8row2_col2" class="data row2 col2" >0.108</td>
#                         <td id="T_e3c94a88_0492_11ec_900f_000d3adfbea8row2_col3" class="data row2 col3" >0.126</td>
#             </tr>
#             <tr>
#                         <th id="T_e3c94a88_0492_11ec_900f_000d3adfbea8level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_e3c94a88_0492_11ec_900f_000d3adfbea8row3_col0" class="data row3 col0" >1.03e+04</td>
#                         <td id="T_e3c94a88_0492_11ec_900f_000d3adfbea8row3_col1" class="data row3 col1" >1.1e+04</td>
#                         <td id="T_e3c94a88_0492_11ec_900f_000d3adfbea8row3_col2" class="data row3 col2" >0.0779</td>
#                         <td id="T_e3c94a88_0492_11ec_900f_000d3adfbea8row3_col3" class="data row3 col3" >0.0926</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]  Current t_inner = 11245.497 K
# 	Expected t_inner for next iteration = 10153.431 K
#  (base.py:531)
# [tardis.simulation.base][INFO   ]  Starting iteration 5 of 5 (base.py:367)
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 8.742e+42 erg / s
# 	Luminosity absorbed  = 2.834e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Simulation finished in 5 iterations Simulation took 1.57 s
#  (base.py:457)

# %% [markdown]
# By setting up the `log_level` parameter to **"Info"** in the above example, we can check that the logs are at the **"Info"** or higher logging level.

# %% [markdown]
# ### `specific_log_level`

# %% [markdown]
# The `specific_log_level` argument tells the logger to capture log messages set by the `log_level` parameter. It can only take *Boolean* values for input, which are `True` or `False`. Take for example the following:

# %%
sim = run_tardis("tardis_config_logger.yml", log_level="Debug", specific_log_level=True, show_cplots=False)
# Out:
# log_level is defined both in Functional Argument & YAML Configuration {debug section}
# log_level = DEBUG will be used for Log Level Determination
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain NAME column (base.py:172)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain NAME column (base.py:172)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain NAME column (base.py:172)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain NAME column (base.py:172)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: SelectedAtoms->IonizationData->AtomicMass->NumberDensity->Lines->Levels->LinesUpperLevelIndex->LinesLowerLevelIndex->JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: SelectedAtoms->IonizationData->AtomicMass->NumberDensity->Lines->Levels->LinesUpperLevelIndex->LinesLowerLevelIndex->JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.montecarlo.base][DEBUG  ]  Electron scattering switched on (base.py:592)
# TqdmHBox(children=(HTML(value='Iterations:', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# TqdmHBox(children=(HTML(value='Packets:   ', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# VBox(children=(FigureWidget({
#     'data': [{'type': 'scatter', 'uid': '3d2d4ad9-ad1a-445a-832b-5985a63aa4ec', …
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)

# %% [markdown]
# It can be examined that, when we set `specific_log_level` to `True`, the log messages captured were only at the `DEBUG` log level.<br> This allows for logging only specified logging messages for inspection.

# %% [markdown]
# The changes in the captured log messages can be seen when we set `specific_log_level` to `False`.

# %%
sim = run_tardis("tardis_config_logger.yml", log_level="Debug", specific_log_level=False, show_cplots=False)
# Out:
# log_level is defined both in Functional Argument & YAML Configuration {debug section}
# log_level = DEBUG will be used for Log Level Determination
#
# [tardis.plasma.standard_plasmas][INFO   ]  Reading Atomic Data from kurucz_cd23_chianti_H_He.h5 (standard_plasmas.py:92)
# [tardis.io.atom_data.util][INFO   ]  Atom Data kurucz_cd23_chianti_H_He.h5 not found in local path.
# 	Exists in TARDIS Data repo /home/runner/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (util.py:34)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain NAME column (base.py:172)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain NAME column (base.py:172)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain NAME column (base.py:172)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain NAME column (base.py:172)
# [tardis.io.atom_data.base][INFO   ]  Reading Atom Data with: UUID = 6f7b09e887a311e7a06b246e96350010 MD5  = 864f1753714343c41f99cb065710cace  (base.py:204)
# [tardis.io.atom_data.base][INFO   ]  Non provided Atomic Data: synpp_refs, photoionization_data, yg_data, two_photon_data (base.py:209)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: SelectedAtoms->IonizationData->AtomicMass->NumberDensity->Lines->Levels->LinesUpperLevelIndex->LinesLowerLevelIndex->JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: SelectedAtoms->IonizationData->AtomicMass->NumberDensity->Lines->Levels->LinesUpperLevelIndex->LinesLowerLevelIndex->JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.montecarlo.base][DEBUG  ]  Electron scattering switched on (base.py:592)
# [tardis.simulation.base][INFO   ]  Starting iteration 1 of 5 (base.py:367)
# TqdmHBox(children=(HTML(value='Iterations:', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# TqdmHBox(children=(HTML(value='Packets:   ', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 7.947e+42 erg / s
# 	Luminosity absorbed  = 2.654e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Plasma stratification: (base.py:503)
# <style  type="text/css" >
# </style><table id="T_e86c9d42_0492_11ec_900f_000d3adfbea8" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e86c9d42_0492_11ec_900f_000d3adfbea8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e86c9d42_0492_11ec_900f_000d3adfbea8row0_col0" class="data row0 col0" >9.93e+03</td>
#                         <td id="T_e86c9d42_0492_11ec_900f_000d3adfbea8row0_col1" class="data row0 col1" >1.03e+04</td>
#                         <td id="T_e86c9d42_0492_11ec_900f_000d3adfbea8row0_col2" class="data row0 col2" >0.4</td>
#                         <td id="T_e86c9d42_0492_11ec_900f_000d3adfbea8row0_col3" class="data row0 col3" >0.481</td>
#             </tr>
#             <tr>
#                         <th id="T_e86c9d42_0492_11ec_900f_000d3adfbea8level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_e86c9d42_0492_11ec_900f_000d3adfbea8row1_col0" class="data row1 col0" >9.85e+03</td>
#                         <td id="T_e86c9d42_0492_11ec_900f_000d3adfbea8row1_col1" class="data row1 col1" >1.03e+04</td>
#                         <td id="T_e86c9d42_0492_11ec_900f_000d3adfbea8row1_col2" class="data row1 col2" >0.211</td>
#                         <td id="T_e86c9d42_0492_11ec_900f_000d3adfbea8row1_col3" class="data row1 col3" >0.193</td>
#             </tr>
#             <tr>
#                         <th id="T_e86c9d42_0492_11ec_900f_000d3adfbea8level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_e86c9d42_0492_11ec_900f_000d3adfbea8row2_col0" class="data row2 col0" >9.78e+03</td>
#                         <td id="T_e86c9d42_0492_11ec_900f_000d3adfbea8row2_col1" class="data row2 col1" >1.02e+04</td>
#                         <td id="T_e86c9d42_0492_11ec_900f_000d3adfbea8row2_col2" class="data row2 col2" >0.143</td>
#                         <td id="T_e86c9d42_0492_11ec_900f_000d3adfbea8row2_col3" class="data row2 col3" >0.112</td>
#             </tr>
#             <tr>
#                         <th id="T_e86c9d42_0492_11ec_900f_000d3adfbea8level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_e86c9d42_0492_11ec_900f_000d3adfbea8row3_col0" class="data row3 col0" >9.71e+03</td>
#                         <td id="T_e86c9d42_0492_11ec_900f_000d3adfbea8row3_col1" class="data row3 col1" >9.98e+03</td>
#                         <td id="T_e86c9d42_0492_11ec_900f_000d3adfbea8row3_col2" class="data row3 col2" >0.105</td>
#                         <td id="T_e86c9d42_0492_11ec_900f_000d3adfbea8row3_col3" class="data row3 col3" >0.0826</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]  Current t_inner = 9933.952 K
# 	Expected t_inner for next iteration = 11468.808 K
#  (base.py:531)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# VBox(children=(FigureWidget({
#     'data': [{'type': 'scatter', 'uid': '3eaccbee-7d0c-4768-898c-8c9bce89d1fc', …
# [tardis.simulation.base][INFO   ]  Starting iteration 2 of 5 (base.py:367)
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 1.413e+43 erg / s
# 	Luminosity absorbed  = 4.704e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Plasma stratification: (base.py:503)
# <style  type="text/css" >
# </style><table id="T_e8a50826_0492_11ec_900f_000d3adfbea8" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e8a50826_0492_11ec_900f_000d3adfbea8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e8a50826_0492_11ec_900f_000d3adfbea8row0_col0" class="data row0 col0" >1.03e+04</td>
#                         <td id="T_e8a50826_0492_11ec_900f_000d3adfbea8row0_col1" class="data row0 col1" >1.15e+04</td>
#                         <td id="T_e8a50826_0492_11ec_900f_000d3adfbea8row0_col2" class="data row0 col2" >0.481</td>
#                         <td id="T_e8a50826_0492_11ec_900f_000d3adfbea8row0_col3" class="data row0 col3" >0.555</td>
#             </tr>
#             <tr>
#                         <th id="T_e8a50826_0492_11ec_900f_000d3adfbea8level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_e8a50826_0492_11ec_900f_000d3adfbea8row1_col0" class="data row1 col0" >1.03e+04</td>
#                         <td id="T_e8a50826_0492_11ec_900f_000d3adfbea8row1_col1" class="data row1 col1" >1.17e+04</td>
#                         <td id="T_e8a50826_0492_11ec_900f_000d3adfbea8row1_col2" class="data row1 col2" >0.193</td>
#                         <td id="T_e8a50826_0492_11ec_900f_000d3adfbea8row1_col3" class="data row1 col3" >0.203</td>
#             </tr>
#             <tr>
#                         <th id="T_e8a50826_0492_11ec_900f_000d3adfbea8level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_e8a50826_0492_11ec_900f_000d3adfbea8row2_col0" class="data row2 col0" >1.02e+04</td>
#                         <td id="T_e8a50826_0492_11ec_900f_000d3adfbea8row2_col1" class="data row2 col1" >1.13e+04</td>
#                         <td id="T_e8a50826_0492_11ec_900f_000d3adfbea8row2_col2" class="data row2 col2" >0.112</td>
#                         <td id="T_e8a50826_0492_11ec_900f_000d3adfbea8row2_col3" class="data row2 col3" >0.135</td>
#             </tr>
#             <tr>
#                         <th id="T_e8a50826_0492_11ec_900f_000d3adfbea8level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_e8a50826_0492_11ec_900f_000d3adfbea8row3_col0" class="data row3 col0" >9.98e+03</td>
#                         <td id="T_e8a50826_0492_11ec_900f_000d3adfbea8row3_col1" class="data row3 col1" >1.1e+04</td>
#                         <td id="T_e8a50826_0492_11ec_900f_000d3adfbea8row3_col2" class="data row3 col2" >0.0826</td>
#                         <td id="T_e8a50826_0492_11ec_900f_000d3adfbea8row3_col3" class="data row3 col3" >0.0998</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]  Current t_inner = 11468.808 K
# 	Expected t_inner for next iteration = 9929.475 K
#  (base.py:531)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.simulation.base][INFO   ]  Starting iteration 3 of 5 (base.py:367)
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 8.259e+42 erg / s
# 	Luminosity absorbed  = 2.337e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Plasma stratification: (base.py:503)
# <style  type="text/css" >
# </style><table id="T_e8c4c2ce_0492_11ec_900f_000d3adfbea8" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e8c4c2ce_0492_11ec_900f_000d3adfbea8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e8c4c2ce_0492_11ec_900f_000d3adfbea8row0_col0" class="data row0 col0" >1.15e+04</td>
#                         <td id="T_e8c4c2ce_0492_11ec_900f_000d3adfbea8row0_col1" class="data row0 col1" >1.03e+04</td>
#                         <td id="T_e8c4c2ce_0492_11ec_900f_000d3adfbea8row0_col2" class="data row0 col2" >0.555</td>
#                         <td id="T_e8c4c2ce_0492_11ec_900f_000d3adfbea8row0_col3" class="data row0 col3" >0.468</td>
#             </tr>
#             <tr>
#                         <th id="T_e8c4c2ce_0492_11ec_900f_000d3adfbea8level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_e8c4c2ce_0492_11ec_900f_000d3adfbea8row1_col0" class="data row1 col0" >1.17e+04</td>
#                         <td id="T_e8c4c2ce_0492_11ec_900f_000d3adfbea8row1_col1" class="data row1 col1" >1.05e+04</td>
#                         <td id="T_e8c4c2ce_0492_11ec_900f_000d3adfbea8row1_col2" class="data row1 col2" >0.203</td>
#                         <td id="T_e8c4c2ce_0492_11ec_900f_000d3adfbea8row1_col3" class="data row1 col3" >0.181</td>
#             </tr>
#             <tr>
#                         <th id="T_e8c4c2ce_0492_11ec_900f_000d3adfbea8level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_e8c4c2ce_0492_11ec_900f_000d3adfbea8row2_col0" class="data row2 col0" >1.13e+04</td>
#                         <td id="T_e8c4c2ce_0492_11ec_900f_000d3adfbea8row2_col1" class="data row2 col1" >1.05e+04</td>
#                         <td id="T_e8c4c2ce_0492_11ec_900f_000d3adfbea8row2_col2" class="data row2 col2" >0.135</td>
#                         <td id="T_e8c4c2ce_0492_11ec_900f_000d3adfbea8row2_col3" class="data row2 col3" >0.108</td>
#             </tr>
#             <tr>
#                         <th id="T_e8c4c2ce_0492_11ec_900f_000d3adfbea8level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_e8c4c2ce_0492_11ec_900f_000d3adfbea8row3_col0" class="data row3 col0" >1.1e+04</td>
#                         <td id="T_e8c4c2ce_0492_11ec_900f_000d3adfbea8row3_col1" class="data row3 col1" >1.03e+04</td>
#                         <td id="T_e8c4c2ce_0492_11ec_900f_000d3adfbea8row3_col2" class="data row3 col2" >0.0998</td>
#                         <td id="T_e8c4c2ce_0492_11ec_900f_000d3adfbea8row3_col3" class="data row3 col3" >0.0779</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]  Current t_inner = 9929.475 K
# 	Expected t_inner for next iteration = 11245.497 K
#  (base.py:531)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.simulation.base][INFO   ]  Starting iteration 4 of 5 (base.py:367)
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 1.299e+43 erg / s
# 	Luminosity absorbed  = 4.407e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Plasma stratification: (base.py:503)
# <style  type="text/css" >
# </style><table id="T_e8e08d42_0492_11ec_900f_000d3adfbea8" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e8e08d42_0492_11ec_900f_000d3adfbea8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e8e08d42_0492_11ec_900f_000d3adfbea8row0_col0" class="data row0 col0" >1.03e+04</td>
#                         <td id="T_e8e08d42_0492_11ec_900f_000d3adfbea8row0_col1" class="data row0 col1" >1.14e+04</td>
#                         <td id="T_e8e08d42_0492_11ec_900f_000d3adfbea8row0_col2" class="data row0 col2" >0.468</td>
#                         <td id="T_e8e08d42_0492_11ec_900f_000d3adfbea8row0_col3" class="data row0 col3" >0.527</td>
#             </tr>
#             <tr>
#                         <th id="T_e8e08d42_0492_11ec_900f_000d3adfbea8level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_e8e08d42_0492_11ec_900f_000d3adfbea8row1_col0" class="data row1 col0" >1.05e+04</td>
#                         <td id="T_e8e08d42_0492_11ec_900f_000d3adfbea8row1_col1" class="data row1 col1" >1.13e+04</td>
#                         <td id="T_e8e08d42_0492_11ec_900f_000d3adfbea8row1_col2" class="data row1 col2" >0.181</td>
#                         <td id="T_e8e08d42_0492_11ec_900f_000d3adfbea8row1_col3" class="data row1 col3" >0.225</td>
#             </tr>
#             <tr>
#                         <th id="T_e8e08d42_0492_11ec_900f_000d3adfbea8level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_e8e08d42_0492_11ec_900f_000d3adfbea8row2_col0" class="data row2 col0" >1.05e+04</td>
#                         <td id="T_e8e08d42_0492_11ec_900f_000d3adfbea8row2_col1" class="data row2 col1" >1.12e+04</td>
#                         <td id="T_e8e08d42_0492_11ec_900f_000d3adfbea8row2_col2" class="data row2 col2" >0.108</td>
#                         <td id="T_e8e08d42_0492_11ec_900f_000d3adfbea8row2_col3" class="data row2 col3" >0.126</td>
#             </tr>
#             <tr>
#                         <th id="T_e8e08d42_0492_11ec_900f_000d3adfbea8level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_e8e08d42_0492_11ec_900f_000d3adfbea8row3_col0" class="data row3 col0" >1.03e+04</td>
#                         <td id="T_e8e08d42_0492_11ec_900f_000d3adfbea8row3_col1" class="data row3 col1" >1.1e+04</td>
#                         <td id="T_e8e08d42_0492_11ec_900f_000d3adfbea8row3_col2" class="data row3 col2" >0.0779</td>
#                         <td id="T_e8e08d42_0492_11ec_900f_000d3adfbea8row3_col3" class="data row3 col3" >0.0926</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]  Current t_inner = 11245.497 K
# 	Expected t_inner for next iteration = 10153.431 K
#  (base.py:531)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.simulation.base][INFO   ]  Starting iteration 5 of 5 (base.py:367)
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 8.742e+42 erg / s
# 	Luminosity absorbed  = 2.834e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Simulation finished in 5 iterations Simulation took 1.56 s
#  (base.py:457)

# %% [markdown]
# It can be examined in this example that when we kept `specific_log_level` to `False`, the captured log output includes all log messages from `DEBUG` and higher logging levels, which is the default behavior of the logger.

# %% [markdown]
# ## Logging Configuration (YAML Configuration)

# %% [markdown]
# The behavior of the logging output for the simulation can be configured via the `tardis_config_logger.yml` *(**YAML** Configuration)* file. For setting up the logger via the YAML file, the configuration file must include a `debug` section. An example configuration for the `debug` section can be seen below:

# %% [markdown]
# ```YAML
# ...
# debug:
#   log_level: "Info"
#   specific_log_level : False
# ```

# %% [markdown]
# The `debug` schema includes the `log_level` & `specific_log_level` parameters.

# %% [markdown]
# <div class="alert alert-info" role="alert">
#     The <strong>debug</strong> section of the <strong>YAML</strong> config file is <i>optional</i>. The <strong>log_level</strong> and the <strong>specific_log_level</strong> arguments are <i>optional</i> as well. If none of the parameters are defined, then the values of these parameter fall back on the <strong>default values</strong>.
# </div>

# %% [markdown]
# Let us load the `tardis_config_logger.yml` configuration to a variable & check out the schema:

# %%
from tardis.io.config_reader import Configuration

# %%
# Loading the Schema 
config = Configuration.from_yaml("tardis_config_logger.yml")

# Checking the Debug Schema via dictionary
config["debug"]
# Out:
# {'specific_log_level': False, 'log_level': 'Critical'}

# %% [markdown]
# ### `log_level`

# %% [markdown]
# The `log_level` parameter, in the `debug` section of the config file, is similar in functionality to the `log_level` functional argument that can be passed via the `run_tardis()` function. The value of this parameter **must be** one of the following: **Notset, Debug, Info, Warning, Error** or **Critical**.

# %% [markdown]
# Let us see an example of the captured simulation logging output, when the `log_level` parameter is set to `"Info"` log level in the `tardis_config_logger.yml` config file.

# %%
config["debug"]["log_level"] = "Info"

# %%
# Running the simulation by passing the config dictionary to `run_tardis()` function
sim = run_tardis(config, show_cplots=False)
# Out:
# [tardis.plasma.standard_plasmas][INFO   ]  Reading Atomic Data from kurucz_cd23_chianti_H_He.h5 (standard_plasmas.py:92)
# [tardis.io.atom_data.util][INFO   ]  Atom Data kurucz_cd23_chianti_H_He.h5 not found in local path.
# 	Exists in TARDIS Data repo /home/runner/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (util.py:34)
# [tardis.io.atom_data.base][INFO   ]  Reading Atom Data with: UUID = 6f7b09e887a311e7a06b246e96350010 MD5  = 864f1753714343c41f99cb065710cace  (base.py:204)
# [tardis.io.atom_data.base][INFO   ]  Non provided Atomic Data: synpp_refs, photoionization_data, yg_data, two_photon_data (base.py:209)
# [tardis.simulation.base][INFO   ]  Starting iteration 1 of 5 (base.py:367)
# TqdmHBox(children=(HTML(value='Iterations:', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# TqdmHBox(children=(HTML(value='Packets:   ', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 7.947e+42 erg / s
# 	Luminosity absorbed  = 2.654e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Plasma stratification: (base.py:503)
# <style  type="text/css" >
# </style><table id="T_eb0d25da_0492_11ec_900f_000d3adfbea8" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_eb0d25da_0492_11ec_900f_000d3adfbea8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_eb0d25da_0492_11ec_900f_000d3adfbea8row0_col0" class="data row0 col0" >9.93e+03</td>
#                         <td id="T_eb0d25da_0492_11ec_900f_000d3adfbea8row0_col1" class="data row0 col1" >1.03e+04</td>
#                         <td id="T_eb0d25da_0492_11ec_900f_000d3adfbea8row0_col2" class="data row0 col2" >0.4</td>
#                         <td id="T_eb0d25da_0492_11ec_900f_000d3adfbea8row0_col3" class="data row0 col3" >0.481</td>
#             </tr>
#             <tr>
#                         <th id="T_eb0d25da_0492_11ec_900f_000d3adfbea8level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_eb0d25da_0492_11ec_900f_000d3adfbea8row1_col0" class="data row1 col0" >9.85e+03</td>
#                         <td id="T_eb0d25da_0492_11ec_900f_000d3adfbea8row1_col1" class="data row1 col1" >1.03e+04</td>
#                         <td id="T_eb0d25da_0492_11ec_900f_000d3adfbea8row1_col2" class="data row1 col2" >0.211</td>
#                         <td id="T_eb0d25da_0492_11ec_900f_000d3adfbea8row1_col3" class="data row1 col3" >0.193</td>
#             </tr>
#             <tr>
#                         <th id="T_eb0d25da_0492_11ec_900f_000d3adfbea8level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_eb0d25da_0492_11ec_900f_000d3adfbea8row2_col0" class="data row2 col0" >9.78e+03</td>
#                         <td id="T_eb0d25da_0492_11ec_900f_000d3adfbea8row2_col1" class="data row2 col1" >1.02e+04</td>
#                         <td id="T_eb0d25da_0492_11ec_900f_000d3adfbea8row2_col2" class="data row2 col2" >0.143</td>
#                         <td id="T_eb0d25da_0492_11ec_900f_000d3adfbea8row2_col3" class="data row2 col3" >0.112</td>
#             </tr>
#             <tr>
#                         <th id="T_eb0d25da_0492_11ec_900f_000d3adfbea8level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_eb0d25da_0492_11ec_900f_000d3adfbea8row3_col0" class="data row3 col0" >9.71e+03</td>
#                         <td id="T_eb0d25da_0492_11ec_900f_000d3adfbea8row3_col1" class="data row3 col1" >9.98e+03</td>
#                         <td id="T_eb0d25da_0492_11ec_900f_000d3adfbea8row3_col2" class="data row3 col2" >0.105</td>
#                         <td id="T_eb0d25da_0492_11ec_900f_000d3adfbea8row3_col3" class="data row3 col3" >0.0826</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]  Current t_inner = 9933.952 K
# 	Expected t_inner for next iteration = 11468.808 K
#  (base.py:531)
# VBox(children=(FigureWidget({
#     'data': [{'type': 'scatter', 'uid': '762f3272-03a5-4098-89bc-90c4613c59ea', …
# [tardis.simulation.base][INFO   ]  Starting iteration 2 of 5 (base.py:367)
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 1.413e+43 erg / s
# 	Luminosity absorbed  = 4.704e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Plasma stratification: (base.py:503)
# <style  type="text/css" >
# </style><table id="T_eb4a0db0_0492_11ec_900f_000d3adfbea8" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_eb4a0db0_0492_11ec_900f_000d3adfbea8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_eb4a0db0_0492_11ec_900f_000d3adfbea8row0_col0" class="data row0 col0" >1.03e+04</td>
#                         <td id="T_eb4a0db0_0492_11ec_900f_000d3adfbea8row0_col1" class="data row0 col1" >1.15e+04</td>
#                         <td id="T_eb4a0db0_0492_11ec_900f_000d3adfbea8row0_col2" class="data row0 col2" >0.481</td>
#                         <td id="T_eb4a0db0_0492_11ec_900f_000d3adfbea8row0_col3" class="data row0 col3" >0.555</td>
#             </tr>
#             <tr>
#                         <th id="T_eb4a0db0_0492_11ec_900f_000d3adfbea8level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_eb4a0db0_0492_11ec_900f_000d3adfbea8row1_col0" class="data row1 col0" >1.03e+04</td>
#                         <td id="T_eb4a0db0_0492_11ec_900f_000d3adfbea8row1_col1" class="data row1 col1" >1.17e+04</td>
#                         <td id="T_eb4a0db0_0492_11ec_900f_000d3adfbea8row1_col2" class="data row1 col2" >0.193</td>
#                         <td id="T_eb4a0db0_0492_11ec_900f_000d3adfbea8row1_col3" class="data row1 col3" >0.203</td>
#             </tr>
#             <tr>
#                         <th id="T_eb4a0db0_0492_11ec_900f_000d3adfbea8level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_eb4a0db0_0492_11ec_900f_000d3adfbea8row2_col0" class="data row2 col0" >1.02e+04</td>
#                         <td id="T_eb4a0db0_0492_11ec_900f_000d3adfbea8row2_col1" class="data row2 col1" >1.13e+04</td>
#                         <td id="T_eb4a0db0_0492_11ec_900f_000d3adfbea8row2_col2" class="data row2 col2" >0.112</td>
#                         <td id="T_eb4a0db0_0492_11ec_900f_000d3adfbea8row2_col3" class="data row2 col3" >0.135</td>
#             </tr>
#             <tr>
#                         <th id="T_eb4a0db0_0492_11ec_900f_000d3adfbea8level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_eb4a0db0_0492_11ec_900f_000d3adfbea8row3_col0" class="data row3 col0" >9.98e+03</td>
#                         <td id="T_eb4a0db0_0492_11ec_900f_000d3adfbea8row3_col1" class="data row3 col1" >1.1e+04</td>
#                         <td id="T_eb4a0db0_0492_11ec_900f_000d3adfbea8row3_col2" class="data row3 col2" >0.0826</td>
#                         <td id="T_eb4a0db0_0492_11ec_900f_000d3adfbea8row3_col3" class="data row3 col3" >0.0998</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]  Current t_inner = 11468.808 K
# 	Expected t_inner for next iteration = 9929.475 K
#  (base.py:531)
# [tardis.simulation.base][INFO   ]  Starting iteration 3 of 5 (base.py:367)
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 8.259e+42 erg / s
# 	Luminosity absorbed  = 2.337e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Plasma stratification: (base.py:503)
# <style  type="text/css" >
# </style><table id="T_eb67998e_0492_11ec_900f_000d3adfbea8" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_eb67998e_0492_11ec_900f_000d3adfbea8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_eb67998e_0492_11ec_900f_000d3adfbea8row0_col0" class="data row0 col0" >1.15e+04</td>
#                         <td id="T_eb67998e_0492_11ec_900f_000d3adfbea8row0_col1" class="data row0 col1" >1.03e+04</td>
#                         <td id="T_eb67998e_0492_11ec_900f_000d3adfbea8row0_col2" class="data row0 col2" >0.555</td>
#                         <td id="T_eb67998e_0492_11ec_900f_000d3adfbea8row0_col3" class="data row0 col3" >0.468</td>
#             </tr>
#             <tr>
#                         <th id="T_eb67998e_0492_11ec_900f_000d3adfbea8level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_eb67998e_0492_11ec_900f_000d3adfbea8row1_col0" class="data row1 col0" >1.17e+04</td>
#                         <td id="T_eb67998e_0492_11ec_900f_000d3adfbea8row1_col1" class="data row1 col1" >1.05e+04</td>
#                         <td id="T_eb67998e_0492_11ec_900f_000d3adfbea8row1_col2" class="data row1 col2" >0.203</td>
#                         <td id="T_eb67998e_0492_11ec_900f_000d3adfbea8row1_col3" class="data row1 col3" >0.181</td>
#             </tr>
#             <tr>
#                         <th id="T_eb67998e_0492_11ec_900f_000d3adfbea8level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_eb67998e_0492_11ec_900f_000d3adfbea8row2_col0" class="data row2 col0" >1.13e+04</td>
#                         <td id="T_eb67998e_0492_11ec_900f_000d3adfbea8row2_col1" class="data row2 col1" >1.05e+04</td>
#                         <td id="T_eb67998e_0492_11ec_900f_000d3adfbea8row2_col2" class="data row2 col2" >0.135</td>
#                         <td id="T_eb67998e_0492_11ec_900f_000d3adfbea8row2_col3" class="data row2 col3" >0.108</td>
#             </tr>
#             <tr>
#                         <th id="T_eb67998e_0492_11ec_900f_000d3adfbea8level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_eb67998e_0492_11ec_900f_000d3adfbea8row3_col0" class="data row3 col0" >1.1e+04</td>
#                         <td id="T_eb67998e_0492_11ec_900f_000d3adfbea8row3_col1" class="data row3 col1" >1.03e+04</td>
#                         <td id="T_eb67998e_0492_11ec_900f_000d3adfbea8row3_col2" class="data row3 col2" >0.0998</td>
#                         <td id="T_eb67998e_0492_11ec_900f_000d3adfbea8row3_col3" class="data row3 col3" >0.0779</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]  Current t_inner = 9929.475 K
# 	Expected t_inner for next iteration = 11245.497 K
#  (base.py:531)
# [tardis.simulation.base][INFO   ]  Starting iteration 4 of 5 (base.py:367)
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 1.299e+43 erg / s
# 	Luminosity absorbed  = 4.407e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Plasma stratification: (base.py:503)
# <style  type="text/css" >
# </style><table id="T_eb86ee56_0492_11ec_900f_000d3adfbea8" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_eb86ee56_0492_11ec_900f_000d3adfbea8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_eb86ee56_0492_11ec_900f_000d3adfbea8row0_col0" class="data row0 col0" >1.03e+04</td>
#                         <td id="T_eb86ee56_0492_11ec_900f_000d3adfbea8row0_col1" class="data row0 col1" >1.14e+04</td>
#                         <td id="T_eb86ee56_0492_11ec_900f_000d3adfbea8row0_col2" class="data row0 col2" >0.468</td>
#                         <td id="T_eb86ee56_0492_11ec_900f_000d3adfbea8row0_col3" class="data row0 col3" >0.527</td>
#             </tr>
#             <tr>
#                         <th id="T_eb86ee56_0492_11ec_900f_000d3adfbea8level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_eb86ee56_0492_11ec_900f_000d3adfbea8row1_col0" class="data row1 col0" >1.05e+04</td>
#                         <td id="T_eb86ee56_0492_11ec_900f_000d3adfbea8row1_col1" class="data row1 col1" >1.13e+04</td>
#                         <td id="T_eb86ee56_0492_11ec_900f_000d3adfbea8row1_col2" class="data row1 col2" >0.181</td>
#                         <td id="T_eb86ee56_0492_11ec_900f_000d3adfbea8row1_col3" class="data row1 col3" >0.225</td>
#             </tr>
#             <tr>
#                         <th id="T_eb86ee56_0492_11ec_900f_000d3adfbea8level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_eb86ee56_0492_11ec_900f_000d3adfbea8row2_col0" class="data row2 col0" >1.05e+04</td>
#                         <td id="T_eb86ee56_0492_11ec_900f_000d3adfbea8row2_col1" class="data row2 col1" >1.12e+04</td>
#                         <td id="T_eb86ee56_0492_11ec_900f_000d3adfbea8row2_col2" class="data row2 col2" >0.108</td>
#                         <td id="T_eb86ee56_0492_11ec_900f_000d3adfbea8row2_col3" class="data row2 col3" >0.126</td>
#             </tr>
#             <tr>
#                         <th id="T_eb86ee56_0492_11ec_900f_000d3adfbea8level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_eb86ee56_0492_11ec_900f_000d3adfbea8row3_col0" class="data row3 col0" >1.03e+04</td>
#                         <td id="T_eb86ee56_0492_11ec_900f_000d3adfbea8row3_col1" class="data row3 col1" >1.1e+04</td>
#                         <td id="T_eb86ee56_0492_11ec_900f_000d3adfbea8row3_col2" class="data row3 col2" >0.0779</td>
#                         <td id="T_eb86ee56_0492_11ec_900f_000d3adfbea8row3_col3" class="data row3 col3" >0.0926</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]  Current t_inner = 11245.497 K
# 	Expected t_inner for next iteration = 10153.431 K
#  (base.py:531)
# [tardis.simulation.base][INFO   ]  Starting iteration 5 of 5 (base.py:367)
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 8.742e+42 erg / s
# 	Luminosity absorbed  = 2.834e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Simulation finished in 5 iterations Simulation took 1.60 s
#  (base.py:457)

# %% [markdown]
# ### `specific_log_level`

# %% [markdown]
# The `specific_log_level` parameter in the `debug` section of the schema is similar in functionality to the `specific_log_level` functional argument. It takes **Boolean** values, i.e., `True` or `False`. It is an optional parameter.

# %% [markdown]
# Let us see an example when we set `specific_log_level` to `True` at the `Debug` level.

# %%
config["debug"]["log_level"] = "Debug"
config["debug"]["specific_log_level"] = True

# %%
sim = run_tardis(config, show_cplots=False)
# Out:
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain NAME column (base.py:172)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain NAME column (base.py:172)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain NAME column (base.py:172)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain NAME column (base.py:172)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: SelectedAtoms->IonizationData->AtomicMass->NumberDensity->Lines->Levels->LinesUpperLevelIndex->LinesLowerLevelIndex->JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: SelectedAtoms->IonizationData->AtomicMass->NumberDensity->Lines->Levels->LinesUpperLevelIndex->LinesLowerLevelIndex->JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.montecarlo.base][DEBUG  ]  Electron scattering switched on (base.py:592)
# TqdmHBox(children=(HTML(value='Iterations:', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# TqdmHBox(children=(HTML(value='Packets:   ', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# VBox(children=(FigureWidget({
#     'data': [{'type': 'scatter', 'uid': '2e742660-9988-4105-850e-c4cc089cd911', …
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)

# %% [markdown]
# Setting `specific_log_level` to `False` to check the actual output at the `DEBUG` level for the simulation logs.

# %%
config["debug"]["specific_log_level"] = False

# %%
sim = run_tardis(config,show_cplots=False)
# Out:
# [tardis.plasma.standard_plasmas][INFO   ]  Reading Atomic Data from kurucz_cd23_chianti_H_He.h5 (standard_plasmas.py:92)
# [tardis.io.atom_data.util][INFO   ]  Atom Data kurucz_cd23_chianti_H_He.h5 not found in local path.
# 	Exists in TARDIS Data repo /home/runner/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (util.py:34)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain NAME column (base.py:172)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain NAME column (base.py:172)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain NAME column (base.py:172)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain NAME column (base.py:172)
# [tardis.io.atom_data.base][INFO   ]  Reading Atom Data with: UUID = 6f7b09e887a311e7a06b246e96350010 MD5  = 864f1753714343c41f99cb065710cace  (base.py:204)
# [tardis.io.atom_data.base][INFO   ]  Non provided Atomic Data: synpp_refs, photoionization_data, yg_data, two_photon_data (base.py:209)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: SelectedAtoms->IonizationData->AtomicMass->NumberDensity->Lines->Levels->LinesUpperLevelIndex->LinesLowerLevelIndex->JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: SelectedAtoms->IonizationData->AtomicMass->NumberDensity->Lines->Levels->LinesUpperLevelIndex->LinesLowerLevelIndex->JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.montecarlo.base][DEBUG  ]  Electron scattering switched on (base.py:592)
# [tardis.simulation.base][INFO   ]  Starting iteration 1 of 5 (base.py:367)
# TqdmHBox(children=(HTML(value='Iterations:', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# TqdmHBox(children=(HTML(value='Packets:   ', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 7.947e+42 erg / s
# 	Luminosity absorbed  = 2.654e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Plasma stratification: (base.py:503)
# <style  type="text/css" >
# </style><table id="T_eff68fe6_0492_11ec_900f_000d3adfbea8" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_eff68fe6_0492_11ec_900f_000d3adfbea8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_eff68fe6_0492_11ec_900f_000d3adfbea8row0_col0" class="data row0 col0" >9.93e+03</td>
#                         <td id="T_eff68fe6_0492_11ec_900f_000d3adfbea8row0_col1" class="data row0 col1" >1.03e+04</td>
#                         <td id="T_eff68fe6_0492_11ec_900f_000d3adfbea8row0_col2" class="data row0 col2" >0.4</td>
#                         <td id="T_eff68fe6_0492_11ec_900f_000d3adfbea8row0_col3" class="data row0 col3" >0.481</td>
#             </tr>
#             <tr>
#                         <th id="T_eff68fe6_0492_11ec_900f_000d3adfbea8level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_eff68fe6_0492_11ec_900f_000d3adfbea8row1_col0" class="data row1 col0" >9.85e+03</td>
#                         <td id="T_eff68fe6_0492_11ec_900f_000d3adfbea8row1_col1" class="data row1 col1" >1.03e+04</td>
#                         <td id="T_eff68fe6_0492_11ec_900f_000d3adfbea8row1_col2" class="data row1 col2" >0.211</td>
#                         <td id="T_eff68fe6_0492_11ec_900f_000d3adfbea8row1_col3" class="data row1 col3" >0.193</td>
#             </tr>
#             <tr>
#                         <th id="T_eff68fe6_0492_11ec_900f_000d3adfbea8level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_eff68fe6_0492_11ec_900f_000d3adfbea8row2_col0" class="data row2 col0" >9.78e+03</td>
#                         <td id="T_eff68fe6_0492_11ec_900f_000d3adfbea8row2_col1" class="data row2 col1" >1.02e+04</td>
#                         <td id="T_eff68fe6_0492_11ec_900f_000d3adfbea8row2_col2" class="data row2 col2" >0.143</td>
#                         <td id="T_eff68fe6_0492_11ec_900f_000d3adfbea8row2_col3" class="data row2 col3" >0.112</td>
#             </tr>
#             <tr>
#                         <th id="T_eff68fe6_0492_11ec_900f_000d3adfbea8level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_eff68fe6_0492_11ec_900f_000d3adfbea8row3_col0" class="data row3 col0" >9.71e+03</td>
#                         <td id="T_eff68fe6_0492_11ec_900f_000d3adfbea8row3_col1" class="data row3 col1" >9.98e+03</td>
#                         <td id="T_eff68fe6_0492_11ec_900f_000d3adfbea8row3_col2" class="data row3 col2" >0.105</td>
#                         <td id="T_eff68fe6_0492_11ec_900f_000d3adfbea8row3_col3" class="data row3 col3" >0.0826</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]  Current t_inner = 9933.952 K
# 	Expected t_inner for next iteration = 11468.808 K
#  (base.py:531)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# VBox(children=(FigureWidget({
#     'data': [{'type': 'scatter', 'uid': '81f815e7-6650-42ab-8cc6-8c5dacce15c7', …
# [tardis.simulation.base][INFO   ]  Starting iteration 2 of 5 (base.py:367)
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 1.413e+43 erg / s
# 	Luminosity absorbed  = 4.704e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Plasma stratification: (base.py:503)
# <style  type="text/css" >
# </style><table id="T_f02f0524_0492_11ec_900f_000d3adfbea8" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f02f0524_0492_11ec_900f_000d3adfbea8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f02f0524_0492_11ec_900f_000d3adfbea8row0_col0" class="data row0 col0" >1.03e+04</td>
#                         <td id="T_f02f0524_0492_11ec_900f_000d3adfbea8row0_col1" class="data row0 col1" >1.15e+04</td>
#                         <td id="T_f02f0524_0492_11ec_900f_000d3adfbea8row0_col2" class="data row0 col2" >0.481</td>
#                         <td id="T_f02f0524_0492_11ec_900f_000d3adfbea8row0_col3" class="data row0 col3" >0.555</td>
#             </tr>
#             <tr>
#                         <th id="T_f02f0524_0492_11ec_900f_000d3adfbea8level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_f02f0524_0492_11ec_900f_000d3adfbea8row1_col0" class="data row1 col0" >1.03e+04</td>
#                         <td id="T_f02f0524_0492_11ec_900f_000d3adfbea8row1_col1" class="data row1 col1" >1.17e+04</td>
#                         <td id="T_f02f0524_0492_11ec_900f_000d3adfbea8row1_col2" class="data row1 col2" >0.193</td>
#                         <td id="T_f02f0524_0492_11ec_900f_000d3adfbea8row1_col3" class="data row1 col3" >0.203</td>
#             </tr>
#             <tr>
#                         <th id="T_f02f0524_0492_11ec_900f_000d3adfbea8level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_f02f0524_0492_11ec_900f_000d3adfbea8row2_col0" class="data row2 col0" >1.02e+04</td>
#                         <td id="T_f02f0524_0492_11ec_900f_000d3adfbea8row2_col1" class="data row2 col1" >1.13e+04</td>
#                         <td id="T_f02f0524_0492_11ec_900f_000d3adfbea8row2_col2" class="data row2 col2" >0.112</td>
#                         <td id="T_f02f0524_0492_11ec_900f_000d3adfbea8row2_col3" class="data row2 col3" >0.135</td>
#             </tr>
#             <tr>
#                         <th id="T_f02f0524_0492_11ec_900f_000d3adfbea8level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_f02f0524_0492_11ec_900f_000d3adfbea8row3_col0" class="data row3 col0" >9.98e+03</td>
#                         <td id="T_f02f0524_0492_11ec_900f_000d3adfbea8row3_col1" class="data row3 col1" >1.1e+04</td>
#                         <td id="T_f02f0524_0492_11ec_900f_000d3adfbea8row3_col2" class="data row3 col2" >0.0826</td>
#                         <td id="T_f02f0524_0492_11ec_900f_000d3adfbea8row3_col3" class="data row3 col3" >0.0998</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]  Current t_inner = 11468.808 K
# 	Expected t_inner for next iteration = 9929.475 K
#  (base.py:531)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.simulation.base][INFO   ]  Starting iteration 3 of 5 (base.py:367)
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 8.259e+42 erg / s
# 	Luminosity absorbed  = 2.337e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Plasma stratification: (base.py:503)
# <style  type="text/css" >
# </style><table id="T_f04bbc32_0492_11ec_900f_000d3adfbea8" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f04bbc32_0492_11ec_900f_000d3adfbea8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f04bbc32_0492_11ec_900f_000d3adfbea8row0_col0" class="data row0 col0" >1.15e+04</td>
#                         <td id="T_f04bbc32_0492_11ec_900f_000d3adfbea8row0_col1" class="data row0 col1" >1.03e+04</td>
#                         <td id="T_f04bbc32_0492_11ec_900f_000d3adfbea8row0_col2" class="data row0 col2" >0.555</td>
#                         <td id="T_f04bbc32_0492_11ec_900f_000d3adfbea8row0_col3" class="data row0 col3" >0.468</td>
#             </tr>
#             <tr>
#                         <th id="T_f04bbc32_0492_11ec_900f_000d3adfbea8level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_f04bbc32_0492_11ec_900f_000d3adfbea8row1_col0" class="data row1 col0" >1.17e+04</td>
#                         <td id="T_f04bbc32_0492_11ec_900f_000d3adfbea8row1_col1" class="data row1 col1" >1.05e+04</td>
#                         <td id="T_f04bbc32_0492_11ec_900f_000d3adfbea8row1_col2" class="data row1 col2" >0.203</td>
#                         <td id="T_f04bbc32_0492_11ec_900f_000d3adfbea8row1_col3" class="data row1 col3" >0.181</td>
#             </tr>
#             <tr>
#                         <th id="T_f04bbc32_0492_11ec_900f_000d3adfbea8level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_f04bbc32_0492_11ec_900f_000d3adfbea8row2_col0" class="data row2 col0" >1.13e+04</td>
#                         <td id="T_f04bbc32_0492_11ec_900f_000d3adfbea8row2_col1" class="data row2 col1" >1.05e+04</td>
#                         <td id="T_f04bbc32_0492_11ec_900f_000d3adfbea8row2_col2" class="data row2 col2" >0.135</td>
#                         <td id="T_f04bbc32_0492_11ec_900f_000d3adfbea8row2_col3" class="data row2 col3" >0.108</td>
#             </tr>
#             <tr>
#                         <th id="T_f04bbc32_0492_11ec_900f_000d3adfbea8level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_f04bbc32_0492_11ec_900f_000d3adfbea8row3_col0" class="data row3 col0" >1.1e+04</td>
#                         <td id="T_f04bbc32_0492_11ec_900f_000d3adfbea8row3_col1" class="data row3 col1" >1.03e+04</td>
#                         <td id="T_f04bbc32_0492_11ec_900f_000d3adfbea8row3_col2" class="data row3 col2" >0.0998</td>
#                         <td id="T_f04bbc32_0492_11ec_900f_000d3adfbea8row3_col3" class="data row3 col3" >0.0779</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]  Current t_inner = 9929.475 K
# 	Expected t_inner for next iteration = 11245.497 K
#  (base.py:531)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.simulation.base][INFO   ]  Starting iteration 4 of 5 (base.py:367)
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 1.299e+43 erg / s
# 	Luminosity absorbed  = 4.407e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Plasma stratification: (base.py:503)
# <style  type="text/css" >
# </style><table id="T_f0682142_0492_11ec_900f_000d3adfbea8" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f0682142_0492_11ec_900f_000d3adfbea8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f0682142_0492_11ec_900f_000d3adfbea8row0_col0" class="data row0 col0" >1.03e+04</td>
#                         <td id="T_f0682142_0492_11ec_900f_000d3adfbea8row0_col1" class="data row0 col1" >1.14e+04</td>
#                         <td id="T_f0682142_0492_11ec_900f_000d3adfbea8row0_col2" class="data row0 col2" >0.468</td>
#                         <td id="T_f0682142_0492_11ec_900f_000d3adfbea8row0_col3" class="data row0 col3" >0.527</td>
#             </tr>
#             <tr>
#                         <th id="T_f0682142_0492_11ec_900f_000d3adfbea8level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_f0682142_0492_11ec_900f_000d3adfbea8row1_col0" class="data row1 col0" >1.05e+04</td>
#                         <td id="T_f0682142_0492_11ec_900f_000d3adfbea8row1_col1" class="data row1 col1" >1.13e+04</td>
#                         <td id="T_f0682142_0492_11ec_900f_000d3adfbea8row1_col2" class="data row1 col2" >0.181</td>
#                         <td id="T_f0682142_0492_11ec_900f_000d3adfbea8row1_col3" class="data row1 col3" >0.225</td>
#             </tr>
#             <tr>
#                         <th id="T_f0682142_0492_11ec_900f_000d3adfbea8level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_f0682142_0492_11ec_900f_000d3adfbea8row2_col0" class="data row2 col0" >1.05e+04</td>
#                         <td id="T_f0682142_0492_11ec_900f_000d3adfbea8row2_col1" class="data row2 col1" >1.12e+04</td>
#                         <td id="T_f0682142_0492_11ec_900f_000d3adfbea8row2_col2" class="data row2 col2" >0.108</td>
#                         <td id="T_f0682142_0492_11ec_900f_000d3adfbea8row2_col3" class="data row2 col3" >0.126</td>
#             </tr>
#             <tr>
#                         <th id="T_f0682142_0492_11ec_900f_000d3adfbea8level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_f0682142_0492_11ec_900f_000d3adfbea8row3_col0" class="data row3 col0" >1.03e+04</td>
#                         <td id="T_f0682142_0492_11ec_900f_000d3adfbea8row3_col1" class="data row3 col1" >1.1e+04</td>
#                         <td id="T_f0682142_0492_11ec_900f_000d3adfbea8row3_col2" class="data row3 col2" >0.0779</td>
#                         <td id="T_f0682142_0492_11ec_900f_000d3adfbea8row3_col3" class="data row3 col3" >0.0926</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]  Current t_inner = 11245.497 K
# 	Expected t_inner for next iteration = 10153.431 K
#  (base.py:531)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.simulation.base][INFO   ]  Starting iteration 5 of 5 (base.py:367)
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 8.742e+42 erg / s
# 	Luminosity absorbed  = 2.834e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Simulation finished in 5 iterations Simulation took 1.54 s
#  (base.py:457)

# %% [markdown]
# ### What Happens When Both Parameters Are Specified? { Function & YAML Arguments }

# %% [markdown]
# If a user specifies both the parameters passed through the `log_level` & `log_level` in the **YAML** configuration file, then the `log_level` parameter *(Functional Argument)* takes precedence & is used to determine the logging level for the simulation logs.

# %% [markdown]
# Let us consider the following example for the configuration:

# %% [markdown]
# Continuing from the previous example, the `config["debug"]["log_level"]` is set to `Debug` via the **YAML** file. The user will also set the `log_level` {Functional Argument} to `Info`.

# %%
sim = run_tardis(config, log_level = "Info", show_cplots=False)
# Out:
# log_level is defined both in Functional Argument & YAML Configuration {debug section}
# log_level = INFO will be used for Log Level Determination
#
# [tardis.plasma.standard_plasmas][INFO   ]  Reading Atomic Data from kurucz_cd23_chianti_H_He.h5 (standard_plasmas.py:92)
# [tardis.io.atom_data.util][INFO   ]  Atom Data kurucz_cd23_chianti_H_He.h5 not found in local path.
# 	Exists in TARDIS Data repo /home/runner/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (util.py:34)
# [tardis.io.atom_data.base][INFO   ]  Reading Atom Data with: UUID = 6f7b09e887a311e7a06b246e96350010 MD5  = 864f1753714343c41f99cb065710cace  (base.py:204)
# [tardis.io.atom_data.base][INFO   ]  Non provided Atomic Data: synpp_refs, photoionization_data, yg_data, two_photon_data (base.py:209)
# [tardis.simulation.base][INFO   ]  Starting iteration 1 of 5 (base.py:367)
# TqdmHBox(children=(HTML(value='Iterations:', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# TqdmHBox(children=(HTML(value='Packets:   ', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 7.947e+42 erg / s
# 	Luminosity absorbed  = 2.654e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Plasma stratification: (base.py:503)
# <style  type="text/css" >
# </style><table id="T_f25ccd0e_0492_11ec_900f_000d3adfbea8" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f25ccd0e_0492_11ec_900f_000d3adfbea8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f25ccd0e_0492_11ec_900f_000d3adfbea8row0_col0" class="data row0 col0" >9.93e+03</td>
#                         <td id="T_f25ccd0e_0492_11ec_900f_000d3adfbea8row0_col1" class="data row0 col1" >1.03e+04</td>
#                         <td id="T_f25ccd0e_0492_11ec_900f_000d3adfbea8row0_col2" class="data row0 col2" >0.4</td>
#                         <td id="T_f25ccd0e_0492_11ec_900f_000d3adfbea8row0_col3" class="data row0 col3" >0.481</td>
#             </tr>
#             <tr>
#                         <th id="T_f25ccd0e_0492_11ec_900f_000d3adfbea8level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_f25ccd0e_0492_11ec_900f_000d3adfbea8row1_col0" class="data row1 col0" >9.85e+03</td>
#                         <td id="T_f25ccd0e_0492_11ec_900f_000d3adfbea8row1_col1" class="data row1 col1" >1.03e+04</td>
#                         <td id="T_f25ccd0e_0492_11ec_900f_000d3adfbea8row1_col2" class="data row1 col2" >0.211</td>
#                         <td id="T_f25ccd0e_0492_11ec_900f_000d3adfbea8row1_col3" class="data row1 col3" >0.193</td>
#             </tr>
#             <tr>
#                         <th id="T_f25ccd0e_0492_11ec_900f_000d3adfbea8level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_f25ccd0e_0492_11ec_900f_000d3adfbea8row2_col0" class="data row2 col0" >9.78e+03</td>
#                         <td id="T_f25ccd0e_0492_11ec_900f_000d3adfbea8row2_col1" class="data row2 col1" >1.02e+04</td>
#                         <td id="T_f25ccd0e_0492_11ec_900f_000d3adfbea8row2_col2" class="data row2 col2" >0.143</td>
#                         <td id="T_f25ccd0e_0492_11ec_900f_000d3adfbea8row2_col3" class="data row2 col3" >0.112</td>
#             </tr>
#             <tr>
#                         <th id="T_f25ccd0e_0492_11ec_900f_000d3adfbea8level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_f25ccd0e_0492_11ec_900f_000d3adfbea8row3_col0" class="data row3 col0" >9.71e+03</td>
#                         <td id="T_f25ccd0e_0492_11ec_900f_000d3adfbea8row3_col1" class="data row3 col1" >9.98e+03</td>
#                         <td id="T_f25ccd0e_0492_11ec_900f_000d3adfbea8row3_col2" class="data row3 col2" >0.105</td>
#                         <td id="T_f25ccd0e_0492_11ec_900f_000d3adfbea8row3_col3" class="data row3 col3" >0.0826</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]  Current t_inner = 9933.952 K
# 	Expected t_inner for next iteration = 11468.808 K
#  (base.py:531)
# VBox(children=(FigureWidget({
#     'data': [{'type': 'scatter', 'uid': 'dfd97ee9-13e6-4629-98c5-1001ff37d422', …
# [tardis.simulation.base][INFO   ]  Starting iteration 2 of 5 (base.py:367)
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 1.413e+43 erg / s
# 	Luminosity absorbed  = 4.704e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Plasma stratification: (base.py:503)
# <style  type="text/css" >
# </style><table id="T_f2970f3c_0492_11ec_900f_000d3adfbea8" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f2970f3c_0492_11ec_900f_000d3adfbea8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f2970f3c_0492_11ec_900f_000d3adfbea8row0_col0" class="data row0 col0" >1.03e+04</td>
#                         <td id="T_f2970f3c_0492_11ec_900f_000d3adfbea8row0_col1" class="data row0 col1" >1.15e+04</td>
#                         <td id="T_f2970f3c_0492_11ec_900f_000d3adfbea8row0_col2" class="data row0 col2" >0.481</td>
#                         <td id="T_f2970f3c_0492_11ec_900f_000d3adfbea8row0_col3" class="data row0 col3" >0.555</td>
#             </tr>
#             <tr>
#                         <th id="T_f2970f3c_0492_11ec_900f_000d3adfbea8level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_f2970f3c_0492_11ec_900f_000d3adfbea8row1_col0" class="data row1 col0" >1.03e+04</td>
#                         <td id="T_f2970f3c_0492_11ec_900f_000d3adfbea8row1_col1" class="data row1 col1" >1.17e+04</td>
#                         <td id="T_f2970f3c_0492_11ec_900f_000d3adfbea8row1_col2" class="data row1 col2" >0.193</td>
#                         <td id="T_f2970f3c_0492_11ec_900f_000d3adfbea8row1_col3" class="data row1 col3" >0.203</td>
#             </tr>
#             <tr>
#                         <th id="T_f2970f3c_0492_11ec_900f_000d3adfbea8level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_f2970f3c_0492_11ec_900f_000d3adfbea8row2_col0" class="data row2 col0" >1.02e+04</td>
#                         <td id="T_f2970f3c_0492_11ec_900f_000d3adfbea8row2_col1" class="data row2 col1" >1.13e+04</td>
#                         <td id="T_f2970f3c_0492_11ec_900f_000d3adfbea8row2_col2" class="data row2 col2" >0.112</td>
#                         <td id="T_f2970f3c_0492_11ec_900f_000d3adfbea8row2_col3" class="data row2 col3" >0.135</td>
#             </tr>
#             <tr>
#                         <th id="T_f2970f3c_0492_11ec_900f_000d3adfbea8level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_f2970f3c_0492_11ec_900f_000d3adfbea8row3_col0" class="data row3 col0" >9.98e+03</td>
#                         <td id="T_f2970f3c_0492_11ec_900f_000d3adfbea8row3_col1" class="data row3 col1" >1.1e+04</td>
#                         <td id="T_f2970f3c_0492_11ec_900f_000d3adfbea8row3_col2" class="data row3 col2" >0.0826</td>
#                         <td id="T_f2970f3c_0492_11ec_900f_000d3adfbea8row3_col3" class="data row3 col3" >0.0998</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]  Current t_inner = 11468.808 K
# 	Expected t_inner for next iteration = 9929.475 K
#  (base.py:531)
# [tardis.simulation.base][INFO   ]  Starting iteration 3 of 5 (base.py:367)
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 8.259e+42 erg / s
# 	Luminosity absorbed  = 2.337e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Plasma stratification: (base.py:503)
# <style  type="text/css" >
# </style><table id="T_f2b3c618_0492_11ec_900f_000d3adfbea8" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f2b3c618_0492_11ec_900f_000d3adfbea8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f2b3c618_0492_11ec_900f_000d3adfbea8row0_col0" class="data row0 col0" >1.15e+04</td>
#                         <td id="T_f2b3c618_0492_11ec_900f_000d3adfbea8row0_col1" class="data row0 col1" >1.03e+04</td>
#                         <td id="T_f2b3c618_0492_11ec_900f_000d3adfbea8row0_col2" class="data row0 col2" >0.555</td>
#                         <td id="T_f2b3c618_0492_11ec_900f_000d3adfbea8row0_col3" class="data row0 col3" >0.468</td>
#             </tr>
#             <tr>
#                         <th id="T_f2b3c618_0492_11ec_900f_000d3adfbea8level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_f2b3c618_0492_11ec_900f_000d3adfbea8row1_col0" class="data row1 col0" >1.17e+04</td>
#                         <td id="T_f2b3c618_0492_11ec_900f_000d3adfbea8row1_col1" class="data row1 col1" >1.05e+04</td>
#                         <td id="T_f2b3c618_0492_11ec_900f_000d3adfbea8row1_col2" class="data row1 col2" >0.203</td>
#                         <td id="T_f2b3c618_0492_11ec_900f_000d3adfbea8row1_col3" class="data row1 col3" >0.181</td>
#             </tr>
#             <tr>
#                         <th id="T_f2b3c618_0492_11ec_900f_000d3adfbea8level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_f2b3c618_0492_11ec_900f_000d3adfbea8row2_col0" class="data row2 col0" >1.13e+04</td>
#                         <td id="T_f2b3c618_0492_11ec_900f_000d3adfbea8row2_col1" class="data row2 col1" >1.05e+04</td>
#                         <td id="T_f2b3c618_0492_11ec_900f_000d3adfbea8row2_col2" class="data row2 col2" >0.135</td>
#                         <td id="T_f2b3c618_0492_11ec_900f_000d3adfbea8row2_col3" class="data row2 col3" >0.108</td>
#             </tr>
#             <tr>
#                         <th id="T_f2b3c618_0492_11ec_900f_000d3adfbea8level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_f2b3c618_0492_11ec_900f_000d3adfbea8row3_col0" class="data row3 col0" >1.1e+04</td>
#                         <td id="T_f2b3c618_0492_11ec_900f_000d3adfbea8row3_col1" class="data row3 col1" >1.03e+04</td>
#                         <td id="T_f2b3c618_0492_11ec_900f_000d3adfbea8row3_col2" class="data row3 col2" >0.0998</td>
#                         <td id="T_f2b3c618_0492_11ec_900f_000d3adfbea8row3_col3" class="data row3 col3" >0.0779</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]  Current t_inner = 9929.475 K
# 	Expected t_inner for next iteration = 11245.497 K
#  (base.py:531)
# [tardis.simulation.base][INFO   ]  Starting iteration 4 of 5 (base.py:367)
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 1.299e+43 erg / s
# 	Luminosity absorbed  = 4.407e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Plasma stratification: (base.py:503)
# <style  type="text/css" >
# </style><table id="T_f2d2bf64_0492_11ec_900f_000d3adfbea8" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f2d2bf64_0492_11ec_900f_000d3adfbea8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f2d2bf64_0492_11ec_900f_000d3adfbea8row0_col0" class="data row0 col0" >1.03e+04</td>
#                         <td id="T_f2d2bf64_0492_11ec_900f_000d3adfbea8row0_col1" class="data row0 col1" >1.14e+04</td>
#                         <td id="T_f2d2bf64_0492_11ec_900f_000d3adfbea8row0_col2" class="data row0 col2" >0.468</td>
#                         <td id="T_f2d2bf64_0492_11ec_900f_000d3adfbea8row0_col3" class="data row0 col3" >0.527</td>
#             </tr>
#             <tr>
#                         <th id="T_f2d2bf64_0492_11ec_900f_000d3adfbea8level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_f2d2bf64_0492_11ec_900f_000d3adfbea8row1_col0" class="data row1 col0" >1.05e+04</td>
#                         <td id="T_f2d2bf64_0492_11ec_900f_000d3adfbea8row1_col1" class="data row1 col1" >1.13e+04</td>
#                         <td id="T_f2d2bf64_0492_11ec_900f_000d3adfbea8row1_col2" class="data row1 col2" >0.181</td>
#                         <td id="T_f2d2bf64_0492_11ec_900f_000d3adfbea8row1_col3" class="data row1 col3" >0.225</td>
#             </tr>
#             <tr>
#                         <th id="T_f2d2bf64_0492_11ec_900f_000d3adfbea8level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_f2d2bf64_0492_11ec_900f_000d3adfbea8row2_col0" class="data row2 col0" >1.05e+04</td>
#                         <td id="T_f2d2bf64_0492_11ec_900f_000d3adfbea8row2_col1" class="data row2 col1" >1.12e+04</td>
#                         <td id="T_f2d2bf64_0492_11ec_900f_000d3adfbea8row2_col2" class="data row2 col2" >0.108</td>
#                         <td id="T_f2d2bf64_0492_11ec_900f_000d3adfbea8row2_col3" class="data row2 col3" >0.126</td>
#             </tr>
#             <tr>
#                         <th id="T_f2d2bf64_0492_11ec_900f_000d3adfbea8level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_f2d2bf64_0492_11ec_900f_000d3adfbea8row3_col0" class="data row3 col0" >1.03e+04</td>
#                         <td id="T_f2d2bf64_0492_11ec_900f_000d3adfbea8row3_col1" class="data row3 col1" >1.1e+04</td>
#                         <td id="T_f2d2bf64_0492_11ec_900f_000d3adfbea8row3_col2" class="data row3 col2" >0.0779</td>
#                         <td id="T_f2d2bf64_0492_11ec_900f_000d3adfbea8row3_col3" class="data row3 col3" >0.0926</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]  Current t_inner = 11245.497 K
# 	Expected t_inner for next iteration = 10153.431 K
#  (base.py:531)
# [tardis.simulation.base][INFO   ]  Starting iteration 5 of 5 (base.py:367)
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 8.742e+42 erg / s
# 	Luminosity absorbed  = 2.834e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Simulation finished in 5 iterations Simulation took 1.56 s
#  (base.py:457)

# %% [markdown]
# A new message can be seen from the execution of the simulation,
# ```
# log_level is defined both in Functional Argument & YAML Configuration {debug section}
# log_level = Info will be used for Log Level Determination
# ```
# that is informing the user which input log level value will determine the logging level. Thus, `log_level = "Info"` is used for logging the simulation output.

# %% [markdown]
# In regards to the `specific_log_level` parameter, if any of the config input value is `True`, then `specific_log_level` will be set to `True` for the simulation output.

# %%
sim = run_tardis(config, log_level = "Info", specific_log_level = True, show_cplots=False)
# Out:
# log_level is defined both in Functional Argument & YAML Configuration {debug section}
# log_level = INFO will be used for Log Level Determination
#
# [tardis.plasma.standard_plasmas][INFO   ]  Reading Atomic Data from kurucz_cd23_chianti_H_He.h5 (standard_plasmas.py:92)
# [tardis.io.atom_data.util][INFO   ]  Atom Data kurucz_cd23_chianti_H_He.h5 not found in local path.
# 	Exists in TARDIS Data repo /home/runner/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (util.py:34)
# [tardis.io.atom_data.base][INFO   ]  Reading Atom Data with: UUID = 6f7b09e887a311e7a06b246e96350010 MD5  = 864f1753714343c41f99cb065710cace  (base.py:204)
# [tardis.io.atom_data.base][INFO   ]  Non provided Atomic Data: synpp_refs, photoionization_data, yg_data, two_photon_data (base.py:209)
# [tardis.simulation.base][INFO   ]  Starting iteration 1 of 5 (base.py:367)
# TqdmHBox(children=(HTML(value='Iterations:', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# TqdmHBox(children=(HTML(value='Packets:   ', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 7.947e+42 erg / s
# 	Luminosity absorbed  = 2.654e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Plasma stratification: (base.py:503)
# <style  type="text/css" >
# </style><table id="T_f4c97db2_0492_11ec_900f_000d3adfbea8" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f4c97db2_0492_11ec_900f_000d3adfbea8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f4c97db2_0492_11ec_900f_000d3adfbea8row0_col0" class="data row0 col0" >9.93e+03</td>
#                         <td id="T_f4c97db2_0492_11ec_900f_000d3adfbea8row0_col1" class="data row0 col1" >1.03e+04</td>
#                         <td id="T_f4c97db2_0492_11ec_900f_000d3adfbea8row0_col2" class="data row0 col2" >0.4</td>
#                         <td id="T_f4c97db2_0492_11ec_900f_000d3adfbea8row0_col3" class="data row0 col3" >0.481</td>
#             </tr>
#             <tr>
#                         <th id="T_f4c97db2_0492_11ec_900f_000d3adfbea8level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_f4c97db2_0492_11ec_900f_000d3adfbea8row1_col0" class="data row1 col0" >9.85e+03</td>
#                         <td id="T_f4c97db2_0492_11ec_900f_000d3adfbea8row1_col1" class="data row1 col1" >1.03e+04</td>
#                         <td id="T_f4c97db2_0492_11ec_900f_000d3adfbea8row1_col2" class="data row1 col2" >0.211</td>
#                         <td id="T_f4c97db2_0492_11ec_900f_000d3adfbea8row1_col3" class="data row1 col3" >0.193</td>
#             </tr>
#             <tr>
#                         <th id="T_f4c97db2_0492_11ec_900f_000d3adfbea8level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_f4c97db2_0492_11ec_900f_000d3adfbea8row2_col0" class="data row2 col0" >9.78e+03</td>
#                         <td id="T_f4c97db2_0492_11ec_900f_000d3adfbea8row2_col1" class="data row2 col1" >1.02e+04</td>
#                         <td id="T_f4c97db2_0492_11ec_900f_000d3adfbea8row2_col2" class="data row2 col2" >0.143</td>
#                         <td id="T_f4c97db2_0492_11ec_900f_000d3adfbea8row2_col3" class="data row2 col3" >0.112</td>
#             </tr>
#             <tr>
#                         <th id="T_f4c97db2_0492_11ec_900f_000d3adfbea8level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_f4c97db2_0492_11ec_900f_000d3adfbea8row3_col0" class="data row3 col0" >9.71e+03</td>
#                         <td id="T_f4c97db2_0492_11ec_900f_000d3adfbea8row3_col1" class="data row3 col1" >9.98e+03</td>
#                         <td id="T_f4c97db2_0492_11ec_900f_000d3adfbea8row3_col2" class="data row3 col2" >0.105</td>
#                         <td id="T_f4c97db2_0492_11ec_900f_000d3adfbea8row3_col3" class="data row3 col3" >0.0826</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]  Current t_inner = 9933.952 K
# 	Expected t_inner for next iteration = 11468.808 K
#  (base.py:531)
# VBox(children=(FigureWidget({
#     'data': [{'type': 'scatter', 'uid': '2bfbc3b5-42f5-4f3c-9f7d-27e634367e26', …
# [tardis.simulation.base][INFO   ]  Starting iteration 2 of 5 (base.py:367)
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 1.413e+43 erg / s
# 	Luminosity absorbed  = 4.704e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Plasma stratification: (base.py:503)
# <style  type="text/css" >
# </style><table id="T_f504f6a8_0492_11ec_900f_000d3adfbea8" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f504f6a8_0492_11ec_900f_000d3adfbea8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f504f6a8_0492_11ec_900f_000d3adfbea8row0_col0" class="data row0 col0" >1.03e+04</td>
#                         <td id="T_f504f6a8_0492_11ec_900f_000d3adfbea8row0_col1" class="data row0 col1" >1.15e+04</td>
#                         <td id="T_f504f6a8_0492_11ec_900f_000d3adfbea8row0_col2" class="data row0 col2" >0.481</td>
#                         <td id="T_f504f6a8_0492_11ec_900f_000d3adfbea8row0_col3" class="data row0 col3" >0.555</td>
#             </tr>
#             <tr>
#                         <th id="T_f504f6a8_0492_11ec_900f_000d3adfbea8level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_f504f6a8_0492_11ec_900f_000d3adfbea8row1_col0" class="data row1 col0" >1.03e+04</td>
#                         <td id="T_f504f6a8_0492_11ec_900f_000d3adfbea8row1_col1" class="data row1 col1" >1.17e+04</td>
#                         <td id="T_f504f6a8_0492_11ec_900f_000d3adfbea8row1_col2" class="data row1 col2" >0.193</td>
#                         <td id="T_f504f6a8_0492_11ec_900f_000d3adfbea8row1_col3" class="data row1 col3" >0.203</td>
#             </tr>
#             <tr>
#                         <th id="T_f504f6a8_0492_11ec_900f_000d3adfbea8level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_f504f6a8_0492_11ec_900f_000d3adfbea8row2_col0" class="data row2 col0" >1.02e+04</td>
#                         <td id="T_f504f6a8_0492_11ec_900f_000d3adfbea8row2_col1" class="data row2 col1" >1.13e+04</td>
#                         <td id="T_f504f6a8_0492_11ec_900f_000d3adfbea8row2_col2" class="data row2 col2" >0.112</td>
#                         <td id="T_f504f6a8_0492_11ec_900f_000d3adfbea8row2_col3" class="data row2 col3" >0.135</td>
#             </tr>
#             <tr>
#                         <th id="T_f504f6a8_0492_11ec_900f_000d3adfbea8level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_f504f6a8_0492_11ec_900f_000d3adfbea8row3_col0" class="data row3 col0" >9.98e+03</td>
#                         <td id="T_f504f6a8_0492_11ec_900f_000d3adfbea8row3_col1" class="data row3 col1" >1.1e+04</td>
#                         <td id="T_f504f6a8_0492_11ec_900f_000d3adfbea8row3_col2" class="data row3 col2" >0.0826</td>
#                         <td id="T_f504f6a8_0492_11ec_900f_000d3adfbea8row3_col3" class="data row3 col3" >0.0998</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]  Current t_inner = 11468.808 K
# 	Expected t_inner for next iteration = 9929.475 K
#  (base.py:531)
# [tardis.simulation.base][INFO   ]  Starting iteration 3 of 5 (base.py:367)
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 8.259e+42 erg / s
# 	Luminosity absorbed  = 2.337e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Plasma stratification: (base.py:503)
# <style  type="text/css" >
# </style><table id="T_f520d5f8_0492_11ec_900f_000d3adfbea8" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f520d5f8_0492_11ec_900f_000d3adfbea8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f520d5f8_0492_11ec_900f_000d3adfbea8row0_col0" class="data row0 col0" >1.15e+04</td>
#                         <td id="T_f520d5f8_0492_11ec_900f_000d3adfbea8row0_col1" class="data row0 col1" >1.03e+04</td>
#                         <td id="T_f520d5f8_0492_11ec_900f_000d3adfbea8row0_col2" class="data row0 col2" >0.555</td>
#                         <td id="T_f520d5f8_0492_11ec_900f_000d3adfbea8row0_col3" class="data row0 col3" >0.468</td>
#             </tr>
#             <tr>
#                         <th id="T_f520d5f8_0492_11ec_900f_000d3adfbea8level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_f520d5f8_0492_11ec_900f_000d3adfbea8row1_col0" class="data row1 col0" >1.17e+04</td>
#                         <td id="T_f520d5f8_0492_11ec_900f_000d3adfbea8row1_col1" class="data row1 col1" >1.05e+04</td>
#                         <td id="T_f520d5f8_0492_11ec_900f_000d3adfbea8row1_col2" class="data row1 col2" >0.203</td>
#                         <td id="T_f520d5f8_0492_11ec_900f_000d3adfbea8row1_col3" class="data row1 col3" >0.181</td>
#             </tr>
#             <tr>
#                         <th id="T_f520d5f8_0492_11ec_900f_000d3adfbea8level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_f520d5f8_0492_11ec_900f_000d3adfbea8row2_col0" class="data row2 col0" >1.13e+04</td>
#                         <td id="T_f520d5f8_0492_11ec_900f_000d3adfbea8row2_col1" class="data row2 col1" >1.05e+04</td>
#                         <td id="T_f520d5f8_0492_11ec_900f_000d3adfbea8row2_col2" class="data row2 col2" >0.135</td>
#                         <td id="T_f520d5f8_0492_11ec_900f_000d3adfbea8row2_col3" class="data row2 col3" >0.108</td>
#             </tr>
#             <tr>
#                         <th id="T_f520d5f8_0492_11ec_900f_000d3adfbea8level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_f520d5f8_0492_11ec_900f_000d3adfbea8row3_col0" class="data row3 col0" >1.1e+04</td>
#                         <td id="T_f520d5f8_0492_11ec_900f_000d3adfbea8row3_col1" class="data row3 col1" >1.03e+04</td>
#                         <td id="T_f520d5f8_0492_11ec_900f_000d3adfbea8row3_col2" class="data row3 col2" >0.0998</td>
#                         <td id="T_f520d5f8_0492_11ec_900f_000d3adfbea8row3_col3" class="data row3 col3" >0.0779</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]  Current t_inner = 9929.475 K
# 	Expected t_inner for next iteration = 11245.497 K
#  (base.py:531)
# [tardis.simulation.base][INFO   ]  Starting iteration 4 of 5 (base.py:367)
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 1.299e+43 erg / s
# 	Luminosity absorbed  = 4.407e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Plasma stratification: (base.py:503)
# <style  type="text/css" >
# </style><table id="T_f53eaa06_0492_11ec_900f_000d3adfbea8" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f53eaa06_0492_11ec_900f_000d3adfbea8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f53eaa06_0492_11ec_900f_000d3adfbea8row0_col0" class="data row0 col0" >1.03e+04</td>
#                         <td id="T_f53eaa06_0492_11ec_900f_000d3adfbea8row0_col1" class="data row0 col1" >1.14e+04</td>
#                         <td id="T_f53eaa06_0492_11ec_900f_000d3adfbea8row0_col2" class="data row0 col2" >0.468</td>
#                         <td id="T_f53eaa06_0492_11ec_900f_000d3adfbea8row0_col3" class="data row0 col3" >0.527</td>
#             </tr>
#             <tr>
#                         <th id="T_f53eaa06_0492_11ec_900f_000d3adfbea8level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_f53eaa06_0492_11ec_900f_000d3adfbea8row1_col0" class="data row1 col0" >1.05e+04</td>
#                         <td id="T_f53eaa06_0492_11ec_900f_000d3adfbea8row1_col1" class="data row1 col1" >1.13e+04</td>
#                         <td id="T_f53eaa06_0492_11ec_900f_000d3adfbea8row1_col2" class="data row1 col2" >0.181</td>
#                         <td id="T_f53eaa06_0492_11ec_900f_000d3adfbea8row1_col3" class="data row1 col3" >0.225</td>
#             </tr>
#             <tr>
#                         <th id="T_f53eaa06_0492_11ec_900f_000d3adfbea8level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_f53eaa06_0492_11ec_900f_000d3adfbea8row2_col0" class="data row2 col0" >1.05e+04</td>
#                         <td id="T_f53eaa06_0492_11ec_900f_000d3adfbea8row2_col1" class="data row2 col1" >1.12e+04</td>
#                         <td id="T_f53eaa06_0492_11ec_900f_000d3adfbea8row2_col2" class="data row2 col2" >0.108</td>
#                         <td id="T_f53eaa06_0492_11ec_900f_000d3adfbea8row2_col3" class="data row2 col3" >0.126</td>
#             </tr>
#             <tr>
#                         <th id="T_f53eaa06_0492_11ec_900f_000d3adfbea8level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_f53eaa06_0492_11ec_900f_000d3adfbea8row3_col0" class="data row3 col0" >1.03e+04</td>
#                         <td id="T_f53eaa06_0492_11ec_900f_000d3adfbea8row3_col1" class="data row3 col1" >1.1e+04</td>
#                         <td id="T_f53eaa06_0492_11ec_900f_000d3adfbea8row3_col2" class="data row3 col2" >0.0779</td>
#                         <td id="T_f53eaa06_0492_11ec_900f_000d3adfbea8row3_col3" class="data row3 col3" >0.0926</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]  Current t_inner = 11245.497 K
# 	Expected t_inner for next iteration = 10153.431 K
#  (base.py:531)
# [tardis.simulation.base][INFO   ]  Starting iteration 5 of 5 (base.py:367)
# [tardis.simulation.base][INFO   ]  Luminosity emitted   = 8.742e+42 erg / s
# 	Luminosity absorbed  = 2.834e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:536)
# [tardis.simulation.base][INFO   ]  Simulation finished in 5 iterations Simulation took 1.57 s
#  (base.py:457)
